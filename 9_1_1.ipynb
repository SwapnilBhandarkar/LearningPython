# %% [markdown]
# ##

# %%
# %%writefile mod.py
s = "If Comrade Napoleon says it, it must be right."
a = [100, 200, 300]

def foo(arg):
    print(f'arg = {arg}')
# Out:
# Overwriting mod.py

# %%
import mod
print(mod.s)
print(mod.a)
mod.foo(['quux', 'corge', 'grault'])
# Out:
# If Comrade Napoleon says it, it must be right.
# [100, 200, 300]
# arg = ['quux', 'corge', 'grault']

# %%
# %%writefile calc.py
def calc(arg1,arg2):
    print("multiplication :",arg1*arg2)
    print("sum :",arg1+arg2)
    print("difference :",arg1-arg2)
    print("divide :",arg1//arg2)
    print("modulo :",arg1%arg2)
# Out:
# Overwriting calc.py

# %%
import calc
calc.calc(10,5)
# Out:
# multiplication : 50
# sum : 15
# difference : 5
# divide : 2
# modulo : 0

# %%
import os
print(os.getcwd())
# Out:
# D:\

# %%
import os
os.chdir('D://')

# %%
import os

os.mkdir('Newpython')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-23-636177214b7c> in <module>
#       1 import os
#       2
# ----> 3 os.mkdir('Newpython')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'Newpython'

# %%
import os
os.listdir('D://')
# Out:
# ['!qhlogs.doc',
#  '$RECYCLE.BIN',
#  '646',
#  'A1_28',
#  'A1_28_T1,T2',
#  'B5_143',
#  'file-0.txt',
#  'file-1.txt',
#  'file-10.txt',
#  'file-100.txt',
#  'file-1000.txt',
#  'file-10000.txt',
#  'file-10001.txt',
#  'file-10002.txt',
#  'file-10003.txt',
#  'file-10004.txt',
#  'file-10005.txt',
#  'file-10006.txt',
#  'file-10007.txt',
#  'file-10008.txt',
#  'file-10009.txt',
#  'file-1001.txt',
#  'file-10010.txt',
#  'file-10011.txt',
#  'file-10012.txt',
#  'file-10013.txt',
#  'file-10014.txt',
#  'file-10015.txt',
#  'file-10016.txt',
#  'file-10017.txt',
#  'file-10018.txt',
#  'file-10019.txt',
#  'file-1002.txt',
#  'file-10020.txt',
#  'file-10021.txt',
#  'file-10022.txt',
#  'file-10023.txt',
#  'file-10024.txt',
#  'file-10025.txt',
#  'file-10026.txt',
#  'file-10027.txt',
#  'file-10028.txt',
#  'file-10029.txt',
#  'file-1003.txt',
#  'file-10030.txt',
#  'file-10031.txt',
#  'file-10032.txt',
#  'file-10033.txt',
#  'file-10034.txt',
#  'file-10035.txt',
# ...

# %%
os.mkdir('new2')
# Out:
# ---------------------------------------------------------------------------
# FileExistsError                           Traceback (most recent call last)
# <ipython-input-5-ccaa023d8e5d> in <module>
# ----> 1 os.mkdir('new2')
#
# FileExistsError: [WinError 183] Cannot create a file when that file already exists: 'new2'

# %%
os.remove('D://file-273.txt')
# Out:
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-8-139cff47f33a> in <module>
# ----> 1 os.remove('D://file-273.txt')
#
# PermissionError: [WinError 5] Access is denied: 'D://file-273.txt'

# %%
os.remove('sofarsogood.txt')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-16-ca0aa2bc8b03> in <module>
# ----> 1 os.remove('sofarsogood.txt')
#
# FileNotFoundError: [WinError 2] The system cannot find the file specified: 'sofarsogood.txt'

# %%
import os
os.rmdir('aaalooo')
# Out:
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-10-c4cf51667ce1> in <module>
#       1 import os
# ----> 2 os.rmdir('aaalooo')
#
# OSError: [WinError 145] The directory is not empty: 'aaalooo'

# %%
import math
math.pi
# Out:
# 3.141592653589793

# %%
s=open('error.txt',w)
s.write('events that ')
